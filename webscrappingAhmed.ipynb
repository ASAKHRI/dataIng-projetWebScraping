# %% [markdown]
# ## WEBSCRAPPING BEAUTIFULSOUP

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import plotly.express as px

# %%
url = "https://books.toscrape.com/"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
titles = soup.find_all("h3")
for title in titles:
  print(title.text)
# Out:
# A Light in the ...
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History ...
# The Requiem Red
# The Dirty Little Secrets ...
# The Coming Woman: A ...
# The Boys in the ...
# The Black Maria
# Starving Hearts (Triangular Trade ...
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little ...
# Rip it Up and ...
# Our Band Could Be ...
# Olio
# Mesaerion: The Best Science ...
# Libertarianism for Beginners
# It's Only the Himalayas

# %%
prices = soup.find_all("div", class_ = "product_price")
p = soup.find_all("p",class_ = "price_color")
for price in p:
  print(price.text)
# Out:
# Â£51.77
# Â£53.74
# Â£50.10
# Â£47.82
# Â£54.23
# Â£22.65
# Â£33.34
# Â£17.93
# Â£22.60
# Â£52.15
# Â£13.99
# Â£20.66
# Â£17.46
# Â£52.29
# Â£35.02
# Â£57.25
# Â£23.88
# Â£37.59
# Â£51.33
# Â£45.17

# %%
prices = soup.find_all("div" , class_ = "price color")
for price in prices:
  print(price.text)

# %%
article = soup.find_all("article")

for articles in article :
    print(articles.p['class'][1])
# Out:
# Three
# One
# One
# Four
# Five
# One
# Four
# Three
# Four
# One
# Two
# Four
# Five
# Five
# Five
# Three
# One
# One
# Two
# Two

# %%
titles = soup.find_all("h3")
prices = soup.find_all("p", class_="price_color")
article = soup.find_all("article")

for title, price, articles in zip(titles, prices, article):
    print(f"Title: {title.text}, Price: {price.text}, Rate:{articles.p['class'][1]}")
# Out:
# Title: A Light in the ..., Price: Â£51.77, Rate:Three
# Title: Tipping the Velvet, Price: Â£53.74, Rate:One
# Title: Soumission, Price: Â£50.10, Rate:One
# Title: Sharp Objects, Price: Â£47.82, Rate:Four
# Title: Sapiens: A Brief History ..., Price: Â£54.23, Rate:Five
# Title: The Requiem Red, Price: Â£22.65, Rate:One
# Title: The Dirty Little Secrets ..., Price: Â£33.34, Rate:Four
# Title: The Coming Woman: A ..., Price: Â£17.93, Rate:Three
# Title: The Boys in the ..., Price: Â£22.60, Rate:Four
# Title: The Black Maria, Price: Â£52.15, Rate:One
# Title: Starving Hearts (Triangular Trade ..., Price: Â£13.99, Rate:Two
# Title: Shakespeare's Sonnets, Price: Â£20.66, Rate:Four
# Title: Set Me Free, Price: Â£17.46, Rate:Five
# Title: Scott Pilgrim's Precious Little ..., Price: Â£52.29, Rate:Five
# Title: Rip it Up and ..., Price: Â£35.02, Rate:Five
# Title: Our Band Could Be ..., Price: Â£57.25, Rate:Three
# Title: Olio, Price: Â£23.88, Rate:One
# ...

# %%
titles = soup.find_all("h3")
prices = soup.find_all("p", class_="price_color")
article = soup.find_all("article")

for title, price, articles in zip(titles, prices, article):
    print(f"Title: {title.text}, Price: {price.text}, Rate:{articles.p['class'][1]}")
# Out:
# Title: A Light in the ..., Price: Â£51.77, Rate:Three
# Title: Tipping the Velvet, Price: Â£53.74, Rate:One
# Title: Soumission, Price: Â£50.10, Rate:One
# Title: Sharp Objects, Price: Â£47.82, Rate:Four
# Title: Sapiens: A Brief History ..., Price: Â£54.23, Rate:Five
# Title: The Requiem Red, Price: Â£22.65, Rate:One
# Title: The Dirty Little Secrets ..., Price: Â£33.34, Rate:Four
# Title: The Coming Woman: A ..., Price: Â£17.93, Rate:Three
# Title: The Boys in the ..., Price: Â£22.60, Rate:Four
# Title: The Black Maria, Price: Â£52.15, Rate:One
# Title: Starving Hearts (Triangular Trade ..., Price: Â£13.99, Rate:Two
# Title: Shakespeare's Sonnets, Price: Â£20.66, Rate:Four
# Title: Set Me Free, Price: Â£17.46, Rate:Five
# Title: Scott Pilgrim's Precious Little ..., Price: Â£52.29, Rate:Five
# Title: Rip it Up and ..., Price: Â£35.02, Rate:Five
# Title: Our Band Could Be ..., Price: Â£57.25, Rate:Three
# Title: Olio, Price: Â£23.88, Rate:One
# ...

# %%
for i in range (1,51):
    url = f"https://books.toscrape.com/catalogue/page-{i}.html"
    page = requests.get(url)
    soup = BeautifulSoup(page.text, "html.parser")


    titles = soup.find_all("h3")
    prices = soup.find_all("p", class_="price_color")
    article = soup.find_all("article")

    for title, price, articles in zip(titles, prices, article):
        print(f"Title: {title.text}, Price: {price.text}, Rate:{articles.p['class'][1]}")
# Out:
# Title: A Light in the ..., Price: Â£51.77, Rate:Three
# Title: Tipping the Velvet, Price: Â£53.74, Rate:One
# Title: Soumission, Price: Â£50.10, Rate:One
# Title: Sharp Objects, Price: Â£47.82, Rate:Four
# Title: Sapiens: A Brief History ..., Price: Â£54.23, Rate:Five
# Title: The Requiem Red, Price: Â£22.65, Rate:One
# Title: The Dirty Little Secrets ..., Price: Â£33.34, Rate:Four
# Title: The Coming Woman: A ..., Price: Â£17.93, Rate:Three
# Title: The Boys in the ..., Price: Â£22.60, Rate:Four
# Title: The Black Maria, Price: Â£52.15, Rate:One
# Title: Starving Hearts (Triangular Trade ..., Price: Â£13.99, Rate:Two
# Title: Shakespeare's Sonnets, Price: Â£20.66, Rate:Four
# Title: Set Me Free, Price: Â£17.46, Rate:Five
# Title: Scott Pilgrim's Precious Little ..., Price: Â£52.29, Rate:Five
# Title: Rip it Up and ..., Price: Â£35.02, Rate:Five
# Title: Our Band Could Be ..., Price: Â£57.25, Rate:Three
# Title: Olio, Price: Â£23.88, Rate:One
# ...

# %%
book_titles = []
book_prices = []
book_ratings = []

for i in range(1, 51):
    url = f"https://books.toscrape.com/catalogue/page-{i}.html"
    page = requests.get(url)
    soup = BeautifulSoup(page.text, "html.parser")
    
    titles = soup.find_all("h3")
    prices = soup.find_all("p", class_="price_color")
    articles = soup.find_all("article")
    
    for title, price, article in zip(titles, prices, articles):
        book_titles.append(title.text)
        book_prices.append(price.text)
        book_ratings.append(article.p['class'][1])

# %%
df = pd.DataFrame({
    'Title': book_titles,
    'Price': book_prices,
    'Rating': book_ratings
})

# %%
df['Price']=df['Price'].str[2:]

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                 Title  Price Rating
# 0                  A Light in the ...  51.77  Three
# 1                  Tipping the Velvet  53.74    One
# 2                          Soumission  50.10    One
# 3                       Sharp Objects  47.82   Four
# 4        Sapiens: A Brief History ...  54.23   Five
# ..                                ...    ...    ...
# 995  Alice in Wonderland (Alice's ...  55.53    One
# 996    Ajin: Demi-Human, Volume 1 ...  57.06   Four
# 997         A Spy's Devotion (The ...  16.97   Five
# 998           1st to Die (Women's ...  53.98    One
# 999           1,000 Places to See ...  26.08   Five
#
# [1000 rows x 3 columns]

# %%
# px.histogram(df,x='Rating')

# %%
# px.histogram(df,x='Price')
